# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from pandas.io.formats.excel import ExcelFormatter

def single_post_fetch(url):
    response = requests.get(url)
    htmlcontent = response.content
    soup = BeautifulSoup(htmlcontent, 'html.parser')

    sp_company_logo = []
    sp_main_title = []
    sp_location = []
    sp_vacancies = []
    sp_availability = []
    sp_main_experience = []
    sp_main_region = []
    sp_main_education = []
    sp_title = []
    sp_categories = []
    sp_salaries = []
    sp_age = []
    sp_gender = []
    sp_designation = []
    sp_vacant_positions = []
    sp_how_to_apply_ol = []

    sp_last_date = []
    sp_online_apply_link = []
    sp_address = []
    sp_advertisement_image_link = []
    sp_application_form_link = []
    sp_inner_ad_img = []


    #Post Company Logo
    sin_pos_logo = soup.select('.container-fluid .freelance-image img')[0]
    sp_company_logo.append(sin_pos_logo.get('data-lazy-src'))
    #Post Main Title
    sin_pos_main_title = soup.select('.header-details h1')[0]
    sp_main_title.append(sin_pos_main_title.string)
    # Post Location
    sin_pos_main_location = soup.select('.header-details p')[1]
    sp_location.append(sin_pos_main_location.get_text())
    # Post Vacancies
    sin_pos_main_vacancies = soup.select('.header-details ul li')[0]
    sp_vacancies.append(sin_pos_main_vacancies.get_text())

    # Right Side Details
    # Post Availability
    sin_pos_main_availibility = soup.select('.right-side-detail ul li')[0]
    sp_availability.append(sin_pos_main_availibility.get_text())
    # Post Expererience
    sin_pos_main_experience = soup.select('.right-side-detail ul li')[1]
    sp_main_experience.append(sin_pos_main_experience.get_text())
    # Post Region
    sin_pos_main_region = soup.select('.right-side-detail ul li')[2]
    sp_main_region.append(sin_pos_main_region.get_text())
    # Post Education
    sin_pos_main_education = soup.select('.right-side-detail ul li')[3]
    sp_main_education.append(sin_pos_main_education.get_text())
    # Post Title
    sin_pos_title = soup.select('.stickyrow .stickycol9 h2')[0]
    sp_title.append(sin_pos_title.string)
    # Category
    sin_pos_cat = soup.select('.stickyrow .post-meta div:nth-child(2) span a')[0]
    #print("Categories: "+sin_pos_cat.string)
    sp_categories.append(sin_pos_cat.string)
    # Offered Salary
    sin_pos_salary = soup.select('.stickyrow .ms-4 .key-field')[0]
    sp_salaries.append(sin_pos_salary.string)
    sin_pos_age = soup.select('.stickyrow .ms-4 .key-field')[1]
    sp_age.append(sin_pos_age.string)
    #Gender
    sin_pos_gender = soup.select('.stickyrow .ms-4 .key-field')[2]
    sp_gender.append(sin_pos_gender.string)
    #Designation
    sin_pos_designation = soup.select('.stickyrow .ms-4 .key-field')[4]
    sp_designation.append(sin_pos_designation.get_text())

    #Vaccant Positions
    if "Table of Conte" in str(soup.select('.pcontent')):
        sp_vacant_positions.append(soup.select('.pcontent ul')[1].get_text())
    else:
        sp_vacant_positions.append(soup.select('.pcontent ul')[0].get_text())

    #How to Apply
    sin_pos_how_to_apply = soup.select('.pcontent ol')[0]
    sp_how_to_apply_ol.append(sin_pos_how_to_apply)


    #Lower Section
    for sin_para in soup.select('.pcontent h5 ~ p'):
        sin_para_text = sin_para.get_text()
        
        #if "Application Form" not in sin_para_text:
        #   print("hello")

        if "Last Date" in sin_para_text:
            only_last_date = sin_para.get_text()
            sp_last_date.append(only_last_date)
        elif "To Apply Online" in str(sin_para):
            only_apply_link = sin_para.select('a')[0].get('href')
            sp_online_apply_link.append(only_apply_link)
        elif "Address" in str(sin_para):
            only_address = sin_para.get_text()
            sp_address.append(only_address)
        elif "Advertisement Image" in sin_para_text:
            only_link_ad_img = sin_para.select('a')[0].get('href')
            sp_advertisement_image_link.append(only_link_ad_img)
        elif "Application Form Will" in sin_para_text:
            sp_application_form_link.append("Application Form Will be Available Soon")
        elif "Application Form" in sin_para_text:
            only_app_form_link = sin_para.select('a')[0].get('href')
            sp_application_form_link.append(only_app_form_link)
        else:
            print(sin_para)


    if not sp_last_date:
        sp_last_date.append("Available Soon")
    if not sp_online_apply_link:
        sp_online_apply_link.append("Available Soon")
    if not sp_address:
        sp_address.append("Soon")
    if not sp_application_form_link:
        sp_application_form_link.append("Available Soon")
    if not sp_advertisement_image_link:
        sp_advertisement_image_link.append("Available Soon")
    else:
        #Opening Next Page for Ad Image
        inner_response = requests.get(only_link_ad_img)
        innerhtmlcontent = inner_response.content
        innersoup = BeautifulSoup(innerhtmlcontent, 'html.parser')
        #Next Page Ad Image
        inner_ad_img = innersoup.select('.pcontent img')
        sp_inner_ad_img.append(inner_ad_img[0].get('data-lazy-src'))

    if not sp_inner_ad_img:
        sp_inner_ad_img.append("Not Available")

    single_post_list_wrapper = {'company_logo':sp_company_logo,
                                'main_title':sp_main_title,
                                'location':sp_location,
                                'vacancies':sp_vacancies,
                                'availability':sp_availability,
                                'main_experience':sp_main_experience,
                                'main_region':sp_main_region,
                                'main_education':sp_main_education,
                                'job_title':sp_title,
                                'categories':sp_categories,
                                'salaries':sp_salaries,
                                'age':sp_age,
                                'gender':sp_gender,
                                'designation':sp_designation,
                                'vacant_positions':sp_vacant_positions,
                                'how_to_apply':sp_how_to_apply_ol,
                                'last_date':sp_last_date,
                                'online_apply_link':sp_online_apply_link,
                                'address':sp_address,
                                'advertisement_img_link':sp_advertisement_image_link,
                                'app_form_link':sp_application_form_link,
                                'inner_ad_img':sp_inner_ad_img
                                }
    #print(single_post_list_wrapper)

    #Create DataFrame from list
    single_post_entry_df = pd.DataFrame(single_post_list_wrapper)
    return single_post_entry_df

def extract_main_links():

    urls = [
        #'https://jobsalert.pk/nespak-jobs-latest-advertisement-apply-last-date/55646',
    'https://jobsalert.pk/bank-alafalah-jobs-oct-for-apply-online-employment-opportunities/78188',
    'https://jobsalert.pk/jazz-jobs-in-pakistan-lahore-islamabad-karachi-peshawar-faisalabad/30497',
    'https://jobsalert.pk/garrison-hrdc-skardu-jobs-2017-for-computer-assistant-bps-14-latest/77576'
        # 'https://jobsalert.pk/station-health-organization-jobs-2016-in-lahore-cantt-for-supervisors-labours-driver-latest/39946',
        # 'https://jobsalert.pk/health-department-attock-jobs-may-june-2016-advertisement-latest-vacancies/45641',
        # 'https://jobsalert.pk/health-department-narowal-jobs-2017-for-data-entry-operator-latest/64018',
        # 'https://jobsalert.pk/po-box-71-karachi-jobs-application-form-download-online/91157',
        # 'https://jobsalert.pk/professor-lecturer-jobs-in-the-university-of-balochistan-quetta/10306',
        # 'https://jobsalert.pk/ogdcl-jobs-2017-oil-gas-development-company-current-vacancies/62529',
        # 'https://jobsalert.pk/karachi-shipyard-and-engineering-works-jobs-latest/56446',
        # 'https://jobsalert.pk/federal-govt-employees-housing-foundation-islamabad-jobs-2016-latest-add/47659'
        ]
    final_list_to_merge = []
    for url in urls:
        final_list_to_merge.append(single_post_fetch(url))
        #single_post_fetch(url)
        #     
    final_df = pd.concat(final_list_to_merge, ignore_index=True)
    return final_df

#single_post_fetch('https://jobsalert.pk/nespak-jobs-latest-advertisement-apply-last-date/55646')
extract_main_links()
# Out:
#                                        company_logo  \
# 0  https://jobsalert.pk/images/company/alfalah.webp
# 1     https://jobsalert.pk/images/company/jazz.webp
# 2     https://jobsalert.pk/images/company/army.webp
#
#                                           main_title  \
# 0  Bank Alfalah Jobs 2023 For Graduates Apply Onl...
# 1  Jazz Jobs 2023 in Pakistan, Lahore, Islamabad,...
# 2  Garrison HRDC Hyderabad Cantt Jobs 2023 Garris...
#
#                                             location    vacancies  \
# 0   Bank Al-Falah, Head Office Bank Al-Falah, Hea...   50 Vacancy
# 1    McLeod Rd, Anarkali Bazaar Lahore, Punjab 54000    5 Vacancy
# 2                     Garrison HRDC, Hyderabad Cantt    1 Vacancy
#
#              availability                    main_experience      main_region  \
# 0  Availability FULL_TIME  Experience\n1 - 2 years required.  Region Pakistan
# 1  Availability FULL_TIME  Experience\n3 - 5 years required.  Region Pakistan
# 2  Availability PERMANENT  Experience\n1 - 2 years required.     Region Sindh
#
#                        main_education  \
# 0            Education\nGraduation,\n
# 1  Education\nGraduation,\nMasters,\n
# 2                Education\nMatric,\n
#
#                                            job_title categories  ...  \
# 0  Bank Alfalah Jobs 2023 For Graduates Apply Onl...       Dawn  ...
# 1  Jazz Jobs 2023 in Pakistan, Lahore, Islamabad,...       Jang  ...
# 2  Garrison HRDC Hyderabad Cantt Jobs 2023 Garris...    Express  ...
#
#          gender                                    designation  \
# 0  Male, Female  \nRelationship Manager,\nExecutive Officer,\n
# 1  Male, Female                   \nManagement,\nAccountant,\n
# 2          Male                                    \nDriver,\n
#
#                                     vacant_positions  \
# 0  \nRelationship Executive\nAssociate Premier Re...
# 1  \nExpert Compliance (AML/KYC)\nExpert Account ...
# 2                                         \nDriver\n
#
#                                         how_to_apply  \
# 0  [\n, [Interested and willing applicants are re...
# 1  [\n, [Only eligible candidates should apply on...
# 2  [\n, [Interested applicants are required to se...
#
#                               last_date  \
# 0  Last Date To Apply: April 24, 2023.
# 1                        Available Soon
# 2  Last Date To Apply: 23rd April 2023.
#
#                                    online_apply_link  \
# 0  https://www.bankalfalah.com/careers/career-opp...
# 1                                     Available Soon
# 2                                     Available Soon
#
#                                     address  \
# 0                                      Soon
# 1                                      Soon
# 2  Address: Garrison HRDC, Hyderabad Cantt.
#
#                               advertisement_img_link   app_form_link  \
# 0  https://jobsalert.pk/bank-alafalah-jobs-oct-fo...  Available Soon
# 1                                     Available Soon  Available Soon
# 2  https://jobsalert.pk/garrison-hrdc-skardu-jobs...  Available Soon
#
#                                         inner_ad_img
# 0  https://jobsalert.pk/wp-content/uploads/2022/0...
# 1                                      Not Available
# 2  https://jobsalert.pk/wp-content/uploads/2023/0...
#
# [3 rows x 22 columns]

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
sample_dataframe = {'company_logo':['sp_company_logo'],
                            'main_title':['sp_main_title'],
                            'location':['sp_location'],
                            'vacancies':['sp_vacancies'],
                            'availability':['sp_availability'],
                            'main_experience':['sp_main_experience'],
                            'main_region':['sp_main_region'],
                            'main_education':['sp_main_education'],
                            'job_title':['sp_title'],
                            'categories':['sp_categories'],
                            'salaries':['sp_salaries'],
                            'age':['sp_age'],
                            'gender':['sp_gender'],
                            'designation':['sp_designation'],
                            'vacant_positions':['sp_vacant_positions'],
                            'how_to_apply':['sp_how_to_apply_ol'],
                            'last_date':['sp_last_date'],
                            'online_apply_link':['sp_online_apply_link'],
                            'address':['sp_address'],
                            'advertisement_img_link':['sp_advertisement_image_link'],
                            'app_form_link':['sp_application_form_link'],
                            'inner_ad_img':['sp_inner_ad_img']
                            }
my_df = pd.DataFrame(sample_dataframe)
my_df2 = pd.DataFrame(sample_dataframe)
my_df3 = pd.DataFrame(sample_dataframe)
my_df4 = pd.DataFrame(sample_dataframe)

pd.concat([my_df2,my_df3,my_df4])
# Out:
#       company_logo     main_title     location     vacancies     availability  \
# 0  sp_company_logo  sp_main_title  sp_location  sp_vacancies  sp_availability
# 0  sp_company_logo  sp_main_title  sp_location  sp_vacancies  sp_availability
# 0  sp_company_logo  sp_main_title  sp_location  sp_vacancies  sp_availability
#
#       main_experience     main_region     main_education job_title  \
# 0  sp_main_experience  sp_main_region  sp_main_education  sp_title
# 0  sp_main_experience  sp_main_region  sp_main_education  sp_title
# 0  sp_main_experience  sp_main_region  sp_main_education  sp_title
#
#       categories  ...     gender     designation     vacant_positions  \
# 0  sp_categories  ...  sp_gender  sp_designation  sp_vacant_positions
# 0  sp_categories  ...  sp_gender  sp_designation  sp_vacant_positions
# 0  sp_categories  ...  sp_gender  sp_designation  sp_vacant_positions
#
#          how_to_apply     last_date     online_apply_link     address  \
# 0  sp_how_to_apply_ol  sp_last_date  sp_online_apply_link  sp_address
# 0  sp_how_to_apply_ol  sp_last_date  sp_online_apply_link  sp_address
# 0  sp_how_to_apply_ol  sp_last_date  sp_online_apply_link  sp_address
#
#         advertisement_img_link             app_form_link     inner_ad_img
# 0  sp_advertisement_image_link  sp_application_form_link  sp_inner_ad_img
# 0  sp_advertisement_image_link  sp_application_form_link  sp_inner_ad_img
# 0  sp_advertisement_image_link  sp_application_form_link  sp_inner_ad_img
#
# [3 rows x 22 columns]

# %%
#elif "Advertisement Image" in str(sin_para):
        #only_link_ad_img = sin_para.select('a')[0].get('href')
        #sp_advertisement_image_link.append(only_link_ad_img)
        #print(only_link_ad_img)


#Last Date upper portion
#sin_pos_last_date = soup.select('.lastdate span')[1]
#print("Post Late Date: "+sin_pos_last_date.string)

# Table of Content Start Here
#for sin_pos_para in soup.select('.pcontent p')[1:]:
#    print(sin_pos_para.get_text())



#Iterate on all elements and identify them first
# v_postions = soup.select('.pcontent *')
# for index, vaccant_position in enumerate(v_postions):
#     if "Vacant" in str(vaccant_position):   
#         print(soup.select('.pcontent p')[index+1])
        #print(vaccant_position)
        #print(index)


#All P tag right after h5
# print(len(soup.select('.pcontent h5 ~ p')))

#Extract Only Text direct from element
# only_last_date = sin_para.find(string=True, recursive=False)


# sin_pos_lower_paras = soup.select('.pcontent p')[-4:]
# print(sin_pos_lower_paras)
# print(len(sin_pos_lower_paras))

#Lower Last Date
# sin_pos_lower_last_date = soup.select('div.pcontent > p:nth-child(13) > strong')[0]
# if "Last Date To Apply" in str(sin_pos_lower_last_date):
#     print(sin_pos_lower_last_date.find(string=True, recursive=False))
# else:
#     print("Lower Last Date is not found...!")



# Short Method for Extracting Table Data
# for sin_tr in soup.select('table.table-hover-jobs tr'):
#     for sin_td in sin_tr:
#         print(sin_td, end='')
    



# Main Loop of Automate Whole Process
# for sin_tr in soup.select('table.table-hover-jobs tr'):
#     if sin_tr.find('th'):
#         continue
#     # Extracting posting date
#     job_date = sin_tr.select('td:nth-child(1)')
#     print(job_date[0].string)
    
#     # Extracting post title
#     job_title = sin_tr.select('td:nth-child(2) a')
#     print(job_title[0].string)
#     print(job_title[0].get('href'))
#     # Call here function which extract a single post complete content

#     # Extracting post newspaper
#     job_newspaper = sin_tr.select('td:nth-child(3) span')
#     print(job_newspaper[0].string)

#     # Extracting post last date
#     job_last_date = sin_tr.select('td:nth-child(4) i')
#     print(job_last_date[0].string)
#     print('\n')
    
    
    

#bulk_jobs_posts = soup.select('table.table-hover-jobs tr')
#print(bulk_jobs_posts)



#job_tbl = soup.find_all('table', class_='job-ads-list')
#add_headers = soup.select('.table-hover-jobs')
#print(add_headers)

#for single_header in add_headers:
#    print(single_header)

#print(link.get('src'))

#print(soup.find(id='sample-id'))

# for link in soup.find_all('a'):
#         print(link.get('href'))



#print(soup.prettify())

#soup = BeautifulSoup("<p>Some<b>bad<i>HTML")
#print(soup.prettify())
